# %%
import pandas as pd

# %%
df = pd.read_csv('pk-airports.csv')
df.tail(60)
# Out:
#          id    ident           type
# 124   41626     OPTT  small_airport  \
# 125   32458     OPTA  small_airport
# 126    5474     OP23  small_airport
# 127    5284     OPWN  small_airport
# 128   41645  PK-0012         closed
# 129  341627  PK-0032       heliport
# 130  341628  PK-0033       heliport
# 131  341629  PK-0034       heliport
# 132  341630  PK-0035       heliport
# 133  341631  PK-0036       heliport
# 134  341632  PK-0037       heliport
# 135  341633  PK-0038       heliport
# 136  341634  PK-0039       heliport
# 137  341635  PK-0040       heliport
# 138  341636  PK-0041       heliport
# 139  341637  PK-0042       heliport
# 140  341638  PK-0043       heliport
# 141  354519  PK-0071       heliport
# 142   41636  PK-0003       heliport
# 143  351734  PK-0063       heliport
# 144  351736  PK-0064       heliport
# 145   41637  PK-0004       heliport
# 146  342092  PK-0044         closed
# 147   41638  PK-0005       heliport
# 148  340187  PK-0030       heliport
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184 entries, 0 to 183
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 184 non-null    object
#  1   ident              184 non-null    object
#  2   type               184 non-null    object
#  3   name               184 non-null    object
#  4   latitude_deg       184 non-null    object
#  5   longitude_deg      184 non-null    object
#  6   elevation_ft       161 non-null    object
#  7   continent          184 non-null    object
#  8   country_name       184 non-null    object
#  9   iso_country        184 non-null    object
#  10  region_name        184 non-null    object
#  11  iso_region         184 non-null    object
#  12  local_region       184 non-null    object
#  13  municipality       183 non-null    object
#  14  scheduled_service  184 non-null    object
#  15  gps_code           96 non-null     object
# ...

# %%
df.isna().values.any()
# Out:
# True

# %%
df.isna().sum(axis=0)
# Out:
# id                     0
# ident                  0
# type                   0
# name                   0
# latitude_deg           0
# longitude_deg          0
# elevation_ft          23
# continent              0
# country_name           0
# iso_country            0
# region_name            0
# iso_region             0
# local_region           0
# municipality           1
# scheduled_service      0
# gps_code              88
# iata_code            124
# local_code           158
# home_link            182
# wikipedia_link       125
# keywords             155
# score                  0
# last_updated           0
# dtype: int64

# %%
df['elevation_ft'].fillna(df['elevation_ft'].mode()[0], inplace=True)
df.tail(60)
# Out:
#          id    ident           type
# 124   41626     OPTT  small_airport  \
# 125   32458     OPTA  small_airport
# 126    5474     OP23  small_airport
# 127    5284     OPWN  small_airport
# 128   41645  PK-0012         closed
# 129  341627  PK-0032       heliport
# 130  341628  PK-0033       heliport
# 131  341629  PK-0034       heliport
# 132  341630  PK-0035       heliport
# 133  341631  PK-0036       heliport
# 134  341632  PK-0037       heliport
# 135  341633  PK-0038       heliport
# 136  341634  PK-0039       heliport
# 137  341635  PK-0040       heliport
# 138  341636  PK-0041       heliport
# 139  341637  PK-0042       heliport
# 140  341638  PK-0043       heliport
# 141  354519  PK-0071       heliport
# 142   41636  PK-0003       heliport
# 143  351734  PK-0063       heliport
# 144  351736  PK-0064       heliport
# 145   41637  PK-0004       heliport
# 146  342092  PK-0044         closed
# 147   41638  PK-0005       heliport
# 148  340187  PK-0030       heliport
# ...

# %%
df.isna().sum(axis=0)
# Out:
# id                     0
# ident                  0
# type                   0
# name                   0
# latitude_deg           0
# longitude_deg          0
# elevation_ft           0
# continent              0
# country_name           0
# iso_country            0
# region_name            0
# iso_region             0
# local_region           0
# municipality           1
# scheduled_service      0
# gps_code              88
# iata_code            124
# local_code           158
# home_link            182
# wikipedia_link       125
# keywords             155
# score                  0
# last_updated           0
# dtype: int64

# %%
df['municipality'].fillna(df['municipality'].mode()[0], inplace=True)
df
# Out:
#             id        ident                 type
# 0    #meta +id  #meta +code  #loc +airport +type  \
# 1         5255         OPKC        large_airport
# 2         5274         OPRN        small_airport
# 3         5257         OPLA        large_airport
# 4         5270         OPPS       medium_airport
# ..         ...          ...                  ...
# 179     341246      PK-0031               closed
# 180     351559      PK-0056             heliport
# 181     325944      PK-0022               closed
# 182      41644      PK-0011             heliport
# 183     301278          ZIZ             heliport
#
#                                    name        latitude_deg
# 0                   #loc +airport +name           #geo +lat  \
# 1          Jinnah International Airport             24.9065
# 2                     PAF Base Nur Khan           33.616699
# 3    Allama Iqbal International Airport           31.521601
# 4        Peshawar International Airport  33.993900299072266
# ...

# %%
df.isna().sum(axis=0)
# Out:
# id                     0
# ident                  0
# type                   0
# name                   0
# latitude_deg           0
# longitude_deg          0
# elevation_ft           0
# continent              0
# country_name           0
# iso_country            0
# region_name            0
# iso_region             0
# local_region           0
# municipality           0
# scheduled_service      0
# gps_code              88
# iata_code            124
# local_code           158
# home_link            182
# wikipedia_link       125
# keywords             155
# score                  0
# last_updated           0
# dtype: int64

# %%
df['gps_code'].fillna(df['gps_code'].mode()[0], inplace=True)
df
# Out:
#             id        ident                 type
# 0    #meta +id  #meta +code  #loc +airport +type  \
# 1         5255         OPKC        large_airport
# 2         5274         OPRN        small_airport
# 3         5257         OPLA        large_airport
# 4         5270         OPPS       medium_airport
# ..         ...          ...                  ...
# 179     341246      PK-0031               closed
# 180     351559      PK-0056             heliport
# 181     325944      PK-0022               closed
# 182      41644      PK-0011             heliport
# 183     301278          ZIZ             heliport
#
#                                    name        latitude_deg
# 0                   #loc +airport +name           #geo +lat  \
# 1          Jinnah International Airport             24.9065
# 2                     PAF Base Nur Khan           33.616699
# 3    Allama Iqbal International Airport           31.521601
# 4        Peshawar International Airport  33.993900299072266
# ...

# %%
df['iata_code'].fillna(df['iata_code'].mode()[0], inplace=True)
df
# Out:
#             id        ident                 type
# 0    #meta +id  #meta +code  #loc +airport +type  \
# 1         5255         OPKC        large_airport
# 2         5274         OPRN        small_airport
# 3         5257         OPLA        large_airport
# 4         5270         OPPS       medium_airport
# ..         ...          ...                  ...
# 179     341246      PK-0031               closed
# 180     351559      PK-0056             heliport
# 181     325944      PK-0022               closed
# 182      41644      PK-0011             heliport
# 183     301278          ZIZ             heliport
#
#                                    name        latitude_deg
# 0                   #loc +airport +name           #geo +lat  \
# 1          Jinnah International Airport             24.9065
# 2                     PAF Base Nur Khan           33.616699
# 3    Allama Iqbal International Airport           31.521601
# 4        Peshawar International Airport  33.993900299072266
# ...

# %%
df['local_code'].fillna(df['local_code'].mode()[0], inplace=True)
df
# Out:
#             id        ident                 type
# 0    #meta +id  #meta +code  #loc +airport +type  \
# 1         5255         OPKC        large_airport
# 2         5274         OPRN        small_airport
# 3         5257         OPLA        large_airport
# 4         5270         OPPS       medium_airport
# ..         ...          ...                  ...
# 179     341246      PK-0031               closed
# 180     351559      PK-0056             heliport
# 181     325944      PK-0022               closed
# 182      41644      PK-0011             heliport
# 183     301278          ZIZ             heliport
#
#                                    name        latitude_deg
# 0                   #loc +airport +name           #geo +lat  \
# 1          Jinnah International Airport             24.9065
# 2                     PAF Base Nur Khan           33.616699
# 3    Allama Iqbal International Airport           31.521601
# 4        Peshawar International Airport  33.993900299072266
# ...

# %%
df['home_link'].fillna(df['home_link'].mode()[0], inplace=True)
df['wikipedia_link'].fillna(df['wikipedia_link'].mode()[0], inplace=True)
df['keywords'].fillna(df['keywords'].mode()[0], inplace=True)
df
# Out:
#             id        ident                 type
# 0    #meta +id  #meta +code  #loc +airport +type  \
# 1         5255         OPKC        large_airport
# 2         5274         OPRN        small_airport
# 3         5257         OPLA        large_airport
# 4         5270         OPPS       medium_airport
# ..         ...          ...                  ...
# 179     341246      PK-0031               closed
# 180     351559      PK-0056             heliport
# 181     325944      PK-0022               closed
# 182      41644      PK-0011             heliport
# 183     301278          ZIZ             heliport
#
#                                    name        latitude_deg
# 0                   #loc +airport +name           #geo +lat  \
# 1          Jinnah International Airport             24.9065
# 2                     PAF Base Nur Khan           33.616699
# 3    Allama Iqbal International Airport           31.521601
# 4        Peshawar International Airport  33.993900299072266
# ...

# %%
df.isna().sum(axis=0)
# Out:
# id                   0
# ident                0
# type                 0
# name                 0
# latitude_deg         0
# longitude_deg        0
# elevation_ft         0
# continent            0
# country_name         0
# iso_country          0
# region_name          0
# iso_region           0
# local_region         0
# municipality         0
# scheduled_service    0
# gps_code             0
# iata_code            0
# local_code           0
# home_link            0
# wikipedia_link       0
# keywords             0
# score                0
# last_updated         0
# dtype: int64

# %%
df.isna().values.any()
# Out:
# False
